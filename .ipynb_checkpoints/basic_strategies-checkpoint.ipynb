# %%
import matplotlib.pyplot as plt
import pandas as pd

import paper_utils as pu

# %%
df = pu.load_data(drop_dups=True)
df['mid'] = (df['best_bid'] + df['best_ask']) / 2
df = df[df['best_bid'] != 0].reset_index(drop=True)
df.head()
# Out:
#         date     exdate  strike_price  lifeTime  volume  open_interest  \
# 0 2000-01-03 2000-03-18       1410000        75       0              1
# 1 2000-01-03 2000-01-22       1505000        19       0             50
# 2 2000-01-03 2000-06-17       1350000       166     290          14570
# 3 2000-01-03 2000-01-22       1500000        19      57            505
# 4 2000-01-03 2000-01-22       1540000        19       0              0
#
#    best_bid  best_ask  daysToExpiry     mid
# 0    36.750    38.750            75  37.750
# 1    55.250    57.250            19  56.250
# 2    40.750    42.750           166  41.750
# 3    51.625    53.625            19  52.625
# 4    84.875    86.875            19  85.875

# %%
df_secid = df[['exdate','strike_price']].drop_duplicates().dropna()
df_secid['secid'] = range(len(df_secid))
df_secid.head()
# Out:
#       exdate  strike_price  secid
# 0 2000-03-18       1410000      0
# 1 2000-01-22       1505000      1
# 2 2000-06-17       1350000      2
# 3 2000-01-22       1500000      3
# 4 2000-01-22       1540000      4

# %%
df = df.merge(df_secid, how = 'inner', on = ['exdate','strike_price'], validate = 'm:1')
df.head()
# Out:
#         date     exdate  strike_price  lifeTime  volume  open_interest  \
# 0 2000-01-03 2000-03-18       1410000        75       0              1
# 1 2000-01-04 2000-03-18       1410000        75     532            527
# 2 2000-01-05 2000-03-18       1410000        75    1961           1840
# 3 2000-01-06 2000-03-18       1410000        75    1280           2606
# 4 2000-01-07 2000-03-18       1410000        75      10           2574
#
#    best_bid  best_ask  daysToExpiry     mid  secid
# 0    36.750    38.750            75  37.750      0
# 1    57.125    59.125            74  58.125      0
# 2    55.875    57.875            73  56.875      0
# 3    62.375    64.375            72  63.375      0
# 4    31.500    33.500            71  32.500      0

# %%
import stock_apis as sa
client = sa.get_tiingo_client()

df_spy = client.get_dataframe('SPY','2000-01-03','2019-12-31').reset_index()[['date','close','adjClose']]
df_spy['date'] = pd.to_datetime(df_spy['date']).dt.tz_localize(None)

df_spy.head()
# Out:
#         date     close   adjClose
# 0 2000-01-03  145.4375  98.511539
# 1 2000-01-04  139.7500  94.659133
# 2 2000-01-05  140.0000  94.828469
# 3 2000-01-06  137.7500  93.304440
# 4 2000-01-07  145.7500  98.723210

# %%
df = df.merge(df_spy, how = 'left', on = 'date', validate = 'm:1')
df.head()
# Out:
#         date     exdate  strike_price  lifeTime  volume  open_interest  \
# 0 2000-01-03 2000-03-18       1410000        75       0              1
# 1 2000-01-04 2000-03-18       1410000        75     532            527
# 2 2000-01-05 2000-03-18       1410000        75    1961           1840
# 3 2000-01-06 2000-03-18       1410000        75    1280           2606
# 4 2000-01-07 2000-03-18       1410000        75      10           2574
#
#    best_bid  best_ask  daysToExpiry     mid  secid     close   adjClose
# 0    36.750    38.750            75  37.750      0  145.4375  98.511539
# 1    57.125    59.125            74  58.125      0  139.7500  94.659133
# 2    55.875    57.875            73  56.875      0  140.0000  94.828469
# 3    62.375    64.375            72  63.375      0  137.7500  93.304440
# 4    31.500    33.500            71  32.500      0  145.7500  98.723210

# %%
df['moneyness'] = 1 - df['strike_price'] / df['close'] / 1e4
df['yrMonth'] = df['date'].dt.strftime('%Y-%m')
df_end_of_month = df.groupby('yrMonth')['date'].max().reset_index()
df_end_of_month.columns = ['yrMonth','endOfMonth']
df = df.merge(df_end_of_month, how = 'left', on = 'yrMonth', validate = 'm:1')
df.head()
# Out:
#         date     exdate  strike_price  lifeTime  volume  open_interest  \
# 0 2000-01-03 2000-03-18       1410000        75       0              1
# 1 2000-01-04 2000-03-18       1410000        75     532            527
# 2 2000-01-05 2000-03-18       1410000        75    1961           1840
# 3 2000-01-06 2000-03-18       1410000        75    1280           2606
# 4 2000-01-07 2000-03-18       1410000        75      10           2574
#
#    best_bid  best_ask  daysToExpiry     mid  secid     close   adjClose  \
# 0    36.750    38.750            75  37.750      0  145.4375  98.511539
# 1    57.125    59.125            74  58.125      0  139.7500  94.659133
# 2    55.875    57.875            73  56.875      0  140.0000  94.828469
# 3    62.375    64.375            72  63.375      0  137.7500  93.304440
# 4    31.500    33.500            71  32.500      0  145.7500  98.723210
#
#    moneyness  yrMonth endOfMonth
# 0   0.030511  2000-01 2000-01-31
# 1  -0.008945  2000-01 2000-01-31
# ...

# %%
v0 = 100

td = df['endOfMonth'].min()
idx = df['date'] == td
df_start = df[idx].copy()
idx = df_start['moneyness'] > 0.05
idx&= df_start['daysToExpiry'] > 21
idx&= df_start['volume'] > 0
df_opt_now = df_start[idx].copy().sort_values('mid').iloc[0]
noptions = v0 / df_opt_now['mid']

v_lst = [v0]
n_lst = [noptions]
tds = [td]
opts = [df_opt_now]

# %%
for td in trading_days[1:10]:
    idx = df['date'] == td
    df_now = df[idx].copy()
    idx = df_now['moneyness'] > 0.05
    idx&= df_now['daysToExpiry'] > 21
    idx&= df_now['volume'] > 0
    break
    v_lst.append(df_now[idx][df_now['secid'] == df_opt_now['secid']]['mid'] * noptions)
    
    df_opt_now = df_now[idx].copy().sort_values('mid').iloc[0]
    noptions = v_lst[-1] / df_opt_now['mid']
    
    tds.append(td)
    opts.append(df_opt_now)

# %%
df_tmp = df.groupby('secid')['volume'].median()

# %%
df_tmp[df_tmp > 0]
# Out:
# secid
# 0           88.0
# 2          520.0
# 3           72.0
# 7         1878.0
# 8           17.5
#            ...
# 129949       1.0
# 129954       4.0
# 129959       1.0
# 129962      39.0
# 129963      40.0
# Name: volume, Length: 53470, dtype: float64

# %%
df[a
  ]
# Out:
#           date     exdate  strike_price  lifeTime  volume  open_interest  \
# 763 2000-01-03 2000-03-18        950000        75      25           5439
# 764 2000-01-04 2000-03-18        950000        75       5           5439
# 765 2000-01-05 2000-03-18        950000        75      30           5449
# 766 2000-01-06 2000-03-18        950000        75       0           5449
# 767 2000-01-07 2000-03-18        950000        75      40           5465
# 768 2000-01-10 2000-03-18        950000        75       0           5465
# 769 2000-01-11 2000-03-18        950000        75       0           5465
# 770 2000-01-12 2000-03-18        950000        75      10           5475
# 771 2000-01-13 2000-03-18        950000        75       0           5475
# 772 2000-01-14 2000-03-18        950000        75       1           5474
# 773 2000-01-18 2000-03-18        950000        75       0           5474
# 774 2000-01-25 2000-03-18        950000        75       0           5474
# ...

# %%
df_now[df_now['secid'] == 18]
# Out:
# Empty DataFrame
# Columns: [date, exdate, strike_price, lifeTime, volume, open_interest, best_bid, best_ask, daysToExpiry, mid, secid, close, adjClose, moneyness, yrMonth, endOfMonth]
# Index: []

# %%
df_opt_now
# Out:
# date             2000-01-31 00:00:00
# exdate           2000-03-18 00:00:00
# strike_price                  950000
# lifeTime                          75
# volume                          1504
# open_interest                   6852
# best_bid                        0.25
# best_ask                       0.625
# daysToExpiry                      47
# mid                           0.4375
# secid                             18
# close                        139.562
# adjClose                     94.5321
# moneyness                   0.319301
# yrMonth                      2000-01
# endOfMonth       2000-01-31 00:00:00
# Name: 778, dtype: object

# %%
tds
# Out:
# [Timestamp('2000-01-31 00:00:00'),
#  Timestamp('2000-02-29 00:00:00'),
#  Timestamp('2000-03-31 00:00:00'),
#  Timestamp('2000-04-28 00:00:00'),
#  Timestamp('2000-05-31 00:00:00'),
#  Timestamp('2000-06-30 00:00:00'),
#  Timestamp('2000-07-31 00:00:00'),
#  Timestamp('2000-08-31 00:00:00'),
#  Timestamp('2000-09-29 00:00:00'),
#  Timestamp('2000-10-31 00:00:00')]

# %%
v_lst
# Out:
# [100,
#  Series([], Name: mid, dtype: float64),
#  Series([], Name: mid, dtype: float64),
#  Series([], Name: mid, dtype: float64),
#  915   NaN
#  Name: mid, dtype: float64,
#  915   NaN
#  Name: mid, dtype: float64,
#  915   NaN
#  Name: mid, dtype: float64,
#  915   NaN
#  Name: mid, dtype: float64,
#  915   NaN
#  Name: mid, dtype: float64,
#  915   NaN
#  Name: mid, dtype: float64,
#  915     NaN
#  13080   NaN
#  Name: mid, dtype: float64]

# %%
df_now[idx]
# Out:
# Empty DataFrame
# Columns: [date, exdate, strike_price, lifeTime, volume, open_interest, best_bid, best_ask, daysToExpiry, mid, secid, close, adjClose, moneyness, yrMonth, endOfMonth]
# Index: []

# %%
tds
# Out:
# [Timestamp('2000-01-31 00:00:00'), Timestamp('2000-02-29 00:00:00')]

# %%
opts
# Out:
# [date             2000-01-31 00:00:00
#  exdate           2000-03-18 00:00:00
#  strike_price                  950000
#  lifeTime                          75
#  volume                          1504
#  open_interest                   6852
#  best_bid                        0.25
#  best_ask                       0.625
#  daysToExpiry                      47
#  mid                           0.4375
#  secid                             18
#  close                        139.562
#  adjClose                     94.5321
#  moneyness                   0.319301
#  yrMonth                      2000-01
#  endOfMonth       2000-01-31 00:00:00
#  Name: 778, dtype: object, date             2000-02-29 00:00:00
#  exdate           2000-06-17 00:00:00
#  strike_price                  650000
#  lifeTime                         166
#  volume                             0
#  open_interest                     32
#  best_bid                      0.0625
#  best_ask                         0.5
# ...

# %%
df_opt_now0['secid']
# Out:
# 18

# %%
df[df['secid'] == 18]
# Out:
#           date     exdate  strike_price  lifeTime  volume  open_interest  \
# 763 2000-01-03 2000-03-18        950000        75      25           5439
# 764 2000-01-04 2000-03-18        950000        75       5           5439
# 765 2000-01-05 2000-03-18        950000        75      30           5449
# 766 2000-01-06 2000-03-18        950000        75       0           5449
# 767 2000-01-07 2000-03-18        950000        75      40           5465
# 768 2000-01-10 2000-03-18        950000        75       0           5465
# 769 2000-01-11 2000-03-18        950000        75       0           5465
# 770 2000-01-12 2000-03-18        950000        75      10           5475
# 771 2000-01-13 2000-03-18        950000        75       0           5475
# 772 2000-01-14 2000-03-18        950000        75       1           5474
# 773 2000-01-18 2000-03-18        950000        75       0           5474
# 774 2000-01-25 2000-03-18        950000        75       0           5474
# ...

# %%
df_now[df_now['secid'] == 80]
# Out:
# Empty DataFrame
# Columns: [date, exdate, strike_price, lifeTime, volume, open_interest, best_bid, best_ask, daysToExpiry, mid, secid, close, adjClose, moneyness, yrMonth, endOfMonth]
# Index: []

# %%
df_opt_now
# Out:
# date             2000-02-29 00:00:00
# exdate           2000-06-17 00:00:00
# strike_price                  650000
# lifeTime                         166
# volume                             0
# open_interest                     32
# best_bid                      0.0625
# best_ask                         0.5
# daysToExpiry                     109
# mid                          0.28125
# secid                             94
# close                        137.438
# adjClose                     93.0928
# moneyness                   0.527058
# yrMonth                      2000-02
# endOfMonth       2000-02-29 00:00:00
# Name: 6017, dtype: object

# %%
df_op

# %%
trading_days = sorted(set(df['endOfMonth']))

# %%
idx = df['date'] > df['endOfMonth'].min()
trading_days = sorted(set(df[idx]['date']))

# %%
trading_days
# Out:
# [Timestamp('2000-02-01 00:00:00'),
#  Timestamp('2000-02-02 00:00:00'),
#  Timestamp('2000-02-03 00:00:00'),
#  Timestamp('2000-02-04 00:00:00'),
#  Timestamp('2000-02-07 00:00:00'),
#  Timestamp('2000-02-08 00:00:00'),
#  Timestamp('2000-02-09 00:00:00'),
#  Timestamp('2000-02-10 00:00:00'),
#  Timestamp('2000-02-11 00:00:00'),
#  Timestamp('2000-02-14 00:00:00'),
#  Timestamp('2000-02-15 00:00:00'),
#  Timestamp('2000-02-16 00:00:00'),
#  Timestamp('2000-02-17 00:00:00'),
#  Timestamp('2000-02-18 00:00:00'),
#  Timestamp('2000-02-22 00:00:00'),
#  Timestamp('2000-02-23 00:00:00'),
#  Timestamp('2000-02-24 00:00:00'),
#  Timestamp('2000-02-25 00:00:00'),
#  Timestamp('2000-02-28 00:00:00'),
#  Timestamp('2000-02-29 00:00:00'),
#  Timestamp('2000-03-01 00:00:00'),
#  Timestamp('2000-03-02 00:00:00'),
#  Timestamp('2000-03-03 00:00:00'),
#  Timestamp('2000-03-06 00:00:00'),
#  Timestamp('2000-03-07 00:00:00'),
#  Timestamp('2000-03-08 00:00:00'),
#  Timestamp('2000-03-09 00:00:00'),
# ...

# %%
df_opt0
# Out:
# date             2000-01-31 00:00:00
# exdate           2000-03-18 00:00:00
# strike_price                 1025000
# lifeTime                          75
# volume                             0
# open_interest                  15773
# best_bid                       0.625
# best_ask                       1.125
# daysToExpiry                      47
# adjClose                     94.5321
# moneyness                  0.0777353
# yrMonth                      2000-01
# endOfMonth       2000-01-31 00:00:00
# secid                             68
# mid                            0.875
# Name: 33, dtype: object

# %%
noptions_start
# Out:
# 114.28571428571429

# %%
idx = df['date'] == df['endOfMonth']
idx&= df['moneyness'] <= -0.05
idx&= df['daysToExpiry'] >= 30

# %%
idx.sum()
# Out:
# 99719

# %%
len(idx)
# Out:
# 7573627

# %%
df['mid'] = (df['best_bid'] + df['best_ask']) / 2

# %%
idx = df['moneyness'] < 0.01
idx&= df['moneyness'] > -0.01

# %%
idx.sum()
# Out:
# 290432

# %%
df[idx][df[idx]['daysToExpiry'] == df[idx]['daysToExpiry'].max()]
# Out:
#               date     exdate  strike_price  lifeTime  volume  open_interest  \
# 965226  2009-12-23 2012-12-22      900000.0    1095.0     0.0            0.0
# 1200374 2010-12-22 2013-12-21     1025000.0    1095.0     0.0            0.0
# 1455675 2011-12-21 2014-12-20     1050000.0    1095.0     0.0            0.0
#
#          best_bid  best_ask  daysToExpiry    adjClose  moneyness  yrMonth  \
# 965226       93.8     100.1        1095.0   90.312892   0.003477  2009-12
# 1200374     104.5     112.0        1095.0  103.463193   0.009397  2010-12
# 1455675     152.8     168.7        1095.0  104.274414  -0.006910  2011-12
#
#         endOfMonth     mid
# 965226  2009-12-31   96.95
# 1200374 2010-12-31  108.25
# 1455675 2011-12-30  160.75

# %%
idx = df['exdate'] == pd.to_datetime('2013-12-21')
idx&= df['strike_price'] == 1025000.0
idx&= df['lifeTime'] == 1095.0

# %%
fig, ax = plt.subplots(figsize = (16,9))
df_plt = df[idx][['date','mid']].sort_values('date').reset_index(drop = True)
plt.plot(df_plt['date'], df_plt['mid'])

# %%
df.head()
# Out:
#         date     exdate  strike_price  lifeTime  volume  open_interest  \
# 0 2000-01-03 2000-03-18     1410000.0      75.0     0.0            1.0
# 1 2000-01-03 2000-01-22     1505000.0      19.0     0.0           50.0
# 2 2000-01-03 2000-06-17     1350000.0     166.0   290.0        14570.0
# 3 2000-01-03 2000-01-22     1500000.0      19.0    57.0          505.0
# 4 2000-01-03 2000-01-22     1540000.0      19.0     0.0            0.0
#
#    best_bid  best_ask  daysToExpiry   adjClose  moneyness  yrMonth endOfMonth  \
# 0    36.750    38.750          75.0  98.511539  -0.301337  2000-01 2000-01-31
# 1    55.250    57.250          19.0  98.511539  -0.345438  2000-01 2000-01-31
# 2    40.750    42.750         166.0  98.511539  -0.270285  2000-01 2000-01-31
# 3    51.625    53.625          19.0  98.511539  -0.343256  2000-01 2000-01-31
# 4    84.875    86.875          19.0  98.511539  -0.360315  2000-01 2000-01-31
#
#       mid
# 0  37.750
# 1  56.250
# 2  41.750
# 3  52.625
# 4  85.875

# %%
slct = ['exdate','strike_price','lifeTime','yrMonth','endOfMonth']
calc = ['mid','moneyness','daysToExpiry']
df_monthly = df.groupby(slct)[calc].last().reset_index().sort_values(slct)
df_monthly = df_monthly[df_monthly['exdate'] > df_monthly['endOfMonth']].reset_index(drop=True)

# %%
len(df[['exdate','lifeTime']].drop_duplicates())
# Out:
# 9090

# %%
len(set(df['date']))
# Out:
# 5031
